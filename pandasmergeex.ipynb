# %%
import pandas as pd
df_1=pd.read_csv("mark.csv",header=0)
df_2=pd.read_csv("student.csv",header=0)
df_2.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [2], line 5
#       3 df_2=pd.read_csv("student.csv",header=0)
#       4 df_2.head()
# ----> 5 df=pd.merge(df_1,df_2,on="student_id")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
# ...

# %%
df_2.head()
# Out:
#    Student_id  Age  Gender      Grade Employed
# 0           1   19    Male  1st Class      yes
# 1           2   20  Female  2nd Class       no
# 2           3   18    Male  1st Class       no
# 3           4   21  Female  2nd Class       no
# 4           5   19    Male  1st Class       no

# %%
df=pd.merge(df_1,df_2,on="Student_id")

# %%
df.head()
# Out:
#    Student_id  Mark     City  Age  Gender      Grade Employed
# 0           1    95  Chennai   19    Male  1st Class      yes
# 1           2    70    Delhi   20  Female  2nd Class       no
# 2           3    98   Mumbai   18    Male  1st Class       no
# 3           4    75     Pune   21  Female  2nd Class       no
# 4           5    89    Kochi   19    Male  1st Class       no

# %%
df_1.head()
df_2.head()
df.head()
# Out:
#    Student_id  Mark     City  Age  Gender      Grade Employed
# 0           1    95  Chennai   19    Male  1st Class      yes
# 1           2    70    Delhi   20  Female  2nd Class       no
# 2           3    98   Mumbai   18    Male  1st Class       no
# 3           4    75     Pune   21  Female  2nd Class       no
# 4           5    89    Kochi   19    Male  1st Class       no

# %%
df_1.head()
# Out:
#    Student_id  Mark     City
# 0           1    95  Chennai
# 1           2    70    Delhi
# 2           3    98   Mumbai
# 3           4    75     Pune
# 4           5    89    Kochi

# %%
df_2.head()
# Out:
#    Student_id  Age  Gender      Grade Employed
# 0           1   19    Male  1st Class      yes
# 1           2   20  Female  2nd Class       no
# 2           3   18    Male  1st Class       no
# 3           4   21  Female  2nd Class       no
# 4           5   19    Male  1st Class       no

# %%
df.head()
# Out:
#    Student_id  Mark     City  Age  Gender      Grade Employed
# 0           1    95  Chennai   19    Male  1st Class      yes
# 1           2    70    Delhi   20  Female  2nd Class       no
# 2           3    98   Mumbai   18    Male  1st Class       no
# 3           4    75     Pune   21  Female  2nd Class       no
# 4           5    89    Kochi   19    Male  1st Class       no
